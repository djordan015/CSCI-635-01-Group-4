# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
RS = 678723
data = pd.read_csv("../../data/processed/final_dataset.csv")

feature_cols = [
    'danceability', 'energy', 'valence', 'acousticness', 'instrumentalness',
    'liveness', 'speechiness', 'tempo', 'loudness', 'duration_sec', 'popularity'
]

X = data[feature_cols]
y = data['macro_genre']

print(f"X shape: {X.shape}")
print(f"y shape: {y.shape}")
# Out:
# X shape: (685567, 11)
# y shape: (685567,)

# %%
color = sns.color_palette("hls", 8)

order = data['macro_genre'].value_counts().index
fig, ax = plt.subplots(figsize=(10, 6))
sns.countplot(x='macro_genre', data=data, order=order, palette=, ax=ax)
ax.set_xlabel('Macro Genre')
ax.set_ylabel('Count')
ax.set_title('Distribution of Macro Genre')

for p in ax.patches:
    h = int(p.get_height())
    ax.annotate(f"{h}", (p.get_x() + p.get_width() / 2, h),
                ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/p7/s_lb0zps10nggb3lkc99g6kh0000gn/T/ipykernel_83628/1740373216.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='macro_genre', data=data, order=order, palette=color, ax=ax)
# /var/folders/p7/s_lb0zps10nggb3lkc99g6kh0000gn/T/ipykernel_83628/1740373216.py:5: UserWarning: The palette list has more values (8) than needed (5), which may not be intended.
#   sns.countplot(x='macro_genre', data=data, order=order, palette=color, ax=ax)
