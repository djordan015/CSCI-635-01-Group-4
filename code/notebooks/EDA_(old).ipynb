# %% [markdown]
# # 🎵 HarmonAIze — Model Building Notebook
#
# This notebook builds modles for recommending sonGs on a curated subset of the **Spotify 1 Million Tracks** dataset.
#
# We’ll perform:
#
# 1. Data visualization
# 2. Data cleaning (drop nulls, duplicates)
# 3. Feature selection (audio-based features only)
# 4. Normalization and encoding
# 5. Saving processed data
#
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans

from sklearn.neighbors import KNeighborsClassifier

# %%
data = pd.read_csv("../../data/processed/spotify_features.csv")

X = data
print(f"The shape of the data set is: {X.shape}")
X.head()
# Out:
# The shape of the data set is: (1159748, 14)
#          track_name    artist_name     genre  danceability    energy  \
# 0   I Won't Give Up     Jason Mraz  acoustic     -0.295121 -1.244639
# 1  93 Million Miles     Jason Mraz  acoustic      0.187328 -0.686411
# 2  Do Not Let Me Go  Joshua Hyslop  acoustic     -0.696259 -1.499723
# 3          Fast Car   Boyce Avenue  acoustic     -0.788412 -1.436876
# 4  Sky's Still Blue   Andrew Belle  acoustic     -0.582422  0.559434
#
#     valence  acousticness  instrumentalness  liveness  speechiness     tempo  \
# 0 -1.178954      1.049226         -0.691216 -0.537222    -0.393524  0.403917
# 1  0.221331      0.437937         -0.691179 -0.624753    -0.528338  0.631455
# 2 -1.156609      0.046373         -0.691079 -0.664042    -0.477093  0.619702
# 3  0.195262      1.367548         -0.691216 -0.712781    -0.445557  2.806734
# 4 -0.888469     -0.701259         -0.638350 -0.562088    -0.493649  1.695337
#
#    loudness  duration_sec  popularity
# 0 -0.189488     -0.062859    3.123384
# 1 -0.229613     -0.221997    1.990284
# 2 -0.832373     -0.606319    2.430934
# 3 -0.152002      0.366301    2.493884
# 4  0.626921     -0.035059    2.242084

# %%
unique_artists = X['artist_name'].unique()
print(len(unique_artists))
print(unique_artists)
# Out:
# 64158
# ['Jason Mraz' 'Joshua Hyslop' 'Boyce Avenue' ... 'Air Night' 'Aiera'
#  'Snakefarm']

# %%
data_vis = X
data_vis = data_vis.drop(columns=["artist_name", "track_name", "duration_sec"], axis=1)

correlation_matrix = data_vis.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f", linewidths=.5)
plt.title('Feature Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       1 data_vis = X
#       2 data_vis = data_vis.drop(columns=["artist_name", "track_name", "duration_sec"], axis=1)
# ----> 4 correlation_matrix = data_vis.corr()
#       6 plt.figure(figsize=(8, 6))
#       7 sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f", linewidths=.5)
#
# File ~/PycharmProjects/CSCI-635-01-Group-4/.venv/lib/python3.11/site-packages/pandas/core/frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/PycharmProjects/CSCI-635-01-Group-4/.venv/lib/python3.11/site-packages/pandas/core/frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# File ~/PycharmProjects/CSCI-635-01-Group-4/.venv/lib/python3.11/site-packages/pandas/core/internals/managers.py:1713, in BlockManager.as_array(self, dtype, copy, na_value)
#    1711         arr.flags.writeable = False
#    1712 else:
# -> 1713     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1714     # The underlying data was copied within _interleave, so no need
#    1715     # to further copy if copy=True or setting na_value
#    1717 if na_value is lib.no_default:
#
# File ~/PycharmProjects/CSCI-635-01-Group-4/.venv/lib/python3.11/site-packages/pandas/core/internals/managers.py:1772, in BlockManager._interleave(self, dtype, na_value)
#    1770     else:
#    1771         arr = blk.get_values(dtype)
# -> 1772     result[rl.indexer] = arr
#    1773     itemmask[rl.indexer] = 1
#    1775 if not itemmask.all():
#
# ValueError: could not convert string to float: 'acoustic'

# %% [markdown]
# The heatmap produced from the dataset shows that the following variables are highley correlative:
# - energy and loudness
# - danceability and valence
#
# THe following features are inversely correlated:
# - acousticness and loudness
# - acousticness and energy

# %%
attr = "danceability"


plt.hist(data_vis[attr], bins=10)
plt.xlabel(attr)
plt.show()

# %% [markdown]
# ## Principal Component Analysis

# %%
feature_cols = [
    "danceability", "energy", "valence", "acousticness", "instrumentalness",
    "liveness", "speechiness", "tempo", "loudness", "popularity"
]
data_num = data_vis[feature_cols]  # Only the 11 numeric columns

scaler = StandardScaler()
scaled_data = scaler.fit_transform(data_num)
cols = scaled_data.shape[1]

pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_data)

pca_df = pd.DataFrame(data=principal_components)
print(pca.explained_variance_ratio_)
print(pca_df.shape)
pca_df.head()

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Keep genre separate for labels
genres = data_vis['genre']

# Scale only numeric features
data_num = data_vis[feature_cols]
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data_num)

# Then PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(scaled_data)

# Plot with genre labels
plt.figure(figsize=(12, 8))
for genre in genres.unique():
    mask = genres == genre
    plt.scatter(X_pca[mask, 0], X_pca[mask, 1], label=genre, alpha=0.3, s=5)
plt.legend()
plt.show()
# Out:
# [0.29239377 0.14633295]
# (1159748, 2)
# /Users/prionti/PycharmProjects/CSCI-635-01-Group-4/.venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
RANDOM_STATE = 42
X_train, X_test = train_test_split(X, test_size=0.25, random_state = RANDOM_STATE)

print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
# Out:
# Shape of X_train: (869811, 13)
# Shape of X_test: (289937, 13)

# %% [markdown]
# ## K Means
# The determine a strong number of clusters for this data set, we will measure the Within-Cluster Sum of Squares (WCCS) for each possible k, to identify the "elbow point"

# %%
pca_np = pca_df.to_numpy()
n_clusters = [5, 10, 50, 100, 200, 500, 1000, 1250, 1500]
WCCS = []

for k in n_clusters:
    kmeans = KMeans(n_clusters=k, random_state=RANDOM_STATE, n_init=10)
    kmeans.fit(pca_np)

    inertia = kmeans.inertia_
    WCCS.append(inertia)
    print(f"WCCS for {k}: {inertia}")



plt.plot(n_clusters, WCCS, color="navy", marker="o")
plt.xlabel("n_clusters")
plt.ylabel("WCCS")
plt.title("WCCS by cluster")
plt.show()


labels = kmeans.labels_
centers = kmeans.cluster_centers_
# took 43 mins
# Out:
# WCCS for 5: 1047036.354090066
# WCCS for 10: 560802.1524246263
# WCCS for 50: 123851.69840757025
# WCCS for 100: 63721.035616184265
# WCCS for 200: 32695.841986319152
# WCCS for 500: 13259.977952835225
# WCCS for 1000: 6654.014990560607
# WCCS for 1250: 5331.695396331374
# WCCS for 1500: 4440.325364145207
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 7
#       5 for k in n_clusters:
#       6     kmeans = KMeans(n_clusters=k, random_state=RANDOM_STATE, n_init=10)
# ----> 7     kmeans.fit(pca_np)
#       9     inertia = kmeans.inertia_
#      10     WCCS.append(inertia)
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:1499, in KMeans.fit(self, X, y, sample_weight)
#    1495 best_inertia, best_labels = None, None
#    1497 for i in range(self._n_init):
#    1498     # Initialize centers
# -> 1499     centers_init = self._init_centroids(
#    1500         X,
#    1501         x_squared_norms=x_squared_norms,
#    1502         init=init,
#    1503         random_state=random_state,
#    1504         sample_weight=sample_weight,
#    1505     )
#    1506     if self.verbose:
#    1507         print("Initialization complete")
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:1014, in _BaseKMeans._init_centroids(self, X, x_squared_norms, init, random_state, sample_weight, init_size, n_centroids)
#    1011     sample_weight = sample_weight[init_indices]
#    1013 if isinstance(init, str) and init == "k-means++":
# -> 1014     centers, _ = _kmeans_plusplus(
#    1015         X,
#    1016         n_clusters,
#    1017         random_state=random_state,
#    1018         x_squared_norms=x_squared_norms,
#    1019         sample_weight=sample_weight,
#    1020     )
#    1021 elif isinstance(init, str) and init == "random":
#    1022     seeds = random_state.choice(
#    1023         n_samples,
#    1024         size=n_clusters,
#    1025         replace=False,
#    1026         p=sample_weight / sample_weight.sum(),
#    1027     )
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:251, in _kmeans_plusplus(X, n_clusters, x_squared_norms, sample_weight, random_state, n_local_trials)
#     248 np.clip(candidate_ids, None, closest_dist_sq.size - 1, out=candidate_ids)
#     250 # Compute distances to center candidates
# --> 251 distance_to_candidates = _euclidean_distances(
#     252     X[candidate_ids], X, Y_norm_squared=x_squared_norms, squared=True
#     253 )
#     255 # update closest distances squared and potential for each candidate
#     256 np.minimum(closest_dist_sq, distance_to_candidates, out=distance_to_candidates)
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:424, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     421     distances = _euclidean_distances_upcast(X, XX, Y, YY)
#     422 else:
#     423     # if dtype is already float64, no need to chunk and upcast
# --> 424     distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     425     distances += XX
#     426     distances += YY
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/sklearn/utils/extmath.py:206, in safe_sparse_dot(a, b, dense_output)
#     202 else:
#     203     ret = a @ b
#     205 if (
# --> 206     sparse.issparse(a)
#     207     and sparse.issparse(b)
#     208     and dense_output
#     209     and hasattr(ret, "toarray")
#     210 ):
#     211     return ret.toarray()
#     212 return ret
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/scipy/_lib/_sparse.py:10, in issparse(x)
#       6 class SparseABC(ABC):
#       7     pass
# ---> 10 def issparse(x):
#      11     """Is `x` of a sparse array or sparse matrix type?
#      12
#      13     Parameters
#    (...)     39     False
#      40     """
#      41     return isinstance(x, SparseABC)
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3413, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3409 exec_count = self.execution_count
#    3410 if result.error_in_exec:
#    3411     # Store formatted traceback and error details
#    3412     self.history_manager.exceptions[exec_count] = (
# -> 3413         self._format_exception_for_storage(result.error_in_exec)
#    3414     )
#    3416 # Each cell is a *single* input, regardless of how many lines it has
#    3417 self.execution_count += 1
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3467, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3464         stb = evalue._render_traceback_()
#    3465     else:
#    3466         # Otherwise, use InteractiveTB to format the traceback.
# -> 3467         stb = self.InteractiveTB.structured_traceback(
#    3468             etype, evalue, tb, tb_offset=1
#    3469         )
#    3470 except Exception:
#    3471     # In case formatting fails, fallback to Python's built-in formatting.
#    3472     stb = traceback.format_exception(etype, evalue, tb)
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py:1185, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1183 else:
#    1184     self.tb = etb
# -> 1185 return FormattedTB.structured_traceback(
#    1186     self, etype, evalue, etb, tb_offset, context
#    1187 )
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py:1056, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1053 mode = self.mode
#    1054 if mode in self.verbose_modes:
#    1055     # Verbose modes need a full traceback
# -> 1056     return VerboseTB.structured_traceback(
#    1057         self, etype, evalue, etb, tb_offset, context
#    1058     )
#    1059 elif mode == "Docs":
#    1060     # return DocTB
#    1061     return DocTB(
#    1062         theme_name=self._theme_name,
#    1063         call_pdb=self.call_pdb,
#    (...)   1071         etype, evalue, etb, tb_offset, 1
#    1072     )  # type: ignore[arg-type]
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py:864, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     855 def structured_traceback(
#     856     self,
#     857     etype: type,
#    (...)    861     context: int = 5,
#     862 ) -> list[str]:
#     863     """Return a nice text document describing the traceback."""
# --> 864     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     865         etype, evalue, etb, context, tb_offset
#     866     )
#     868     termsize = min(75, get_terminal_size()[0])
#     869     theme = theme_table[self._theme_name]
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py:776, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     766         frames.append(
#     767             theme_table[self._theme_name].format(
#     768                 [
#    (...)    773             )
#     774         )
#     775         skipped = 0
# --> 776     frames.append(self.format_record(record))
#     777 if skipped:
#     778     frames.append(
#     779         theme_table[self._theme_name].format(
#     780             [
#    (...)    785         )
#     786     )
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py:651, in VerboseTB.format_record(self, frame_info)
#     648 result += ", " if call else ""
#     649 result += f"{call}\n"
#     650 result += theme_table[self._theme_name].format(
# --> 651     _format_traceback_lines(
#     652         frame_info.lines,
#     653         theme_table[self._theme_name],
#     654         self.has_colors,
#     655         lvals_toks,
#     656     )
#     657 )
#     658 return result
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/IPython/core/tbtools.py:99, in _format_traceback_lines(lines, theme, has_colors, lvals_toks)
#      96     continue
#      98 lineno = stack_line.lineno
# ---> 99 line = stack_line.render(pygmented=has_colors).rstrip("\n") + "\n"
#     100 if stack_line.is_current:
#     101     # This is the line with the error
#     102     pad = numbers_width - len(str(lineno))
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/stack_data/core.py:391, in Line.render(self, markers, strip_leading_indent, pygmented, escape_html)
#     389 if pygmented and self.frame_info.scope:
#     390     assert_(not markers, ValueError("Cannot use pygmented with markers"))
# --> 391     start_line, lines = self.frame_info._pygmented_scope_lines
#     392     result = lines[self.lineno - start_line]
#     393     if strip_leading_indent:
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/stack_data/utils.py:145, in cached_property.cached_property_wrapper(self, obj, _cls)
#     142 if obj is None:
#     143     return self
# --> 145 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     146 return value
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/stack_data/core.py:824, in FrameInfo._pygmented_scope_lines(self)
#     821     ranges = []
#     823 code = atext.get_text(scope)
# --> 824 lines = _pygmented_with_ranges(formatter, code, ranges)
#     826 start_line = self.source.line_range(scope)[0]
#     828 return start_line, lines
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/stack_data/utils.py:164, in _pygmented_with_ranges(formatter, code, ranges)
#     161             length += len(value)
#     162             yield ttype, value
# --> 164 lexer = MyLexer(stripnl=False)
#     165 try:
#     166     highlighted = pygments.highlight(code, lexer, formatter)
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/lexer.py:660, in RegexLexerMeta.__call__(cls, *args, **kwds)
#     658         pass
#     659     else:
# --> 660         cls._tokens = cls.process_tokendef('', cls.get_tokendefs())
#     662 return type.__call__(cls, *args, **kwds)
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/lexer.py:599, in RegexLexerMeta.process_tokendef(cls, name, tokendefs)
#     597 tokendefs = tokendefs or cls.tokens[name]
#     598 for state in list(tokendefs):
# --> 599     cls._process_state(tokendefs, processed, state)
#     600 return processed
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/lexer.py:563, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     560 if isinstance(tdef, include):
#     561     # it's a state reference
#     562     assert tdef != state, f"circular state reference {state!r}"
# --> 563     tokens.extend(cls._process_state(unprocessed, processed,
#     564                                      str(tdef)))
#     565     continue
#     566 if isinstance(tdef, _inherit):
#     567     # should be processed already, but may not in the case of:
#     568     # 1. the state has no counterpart in any parent
#     569     # 2. the state includes more than one 'inherit'
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/lexer.py:563, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     560 if isinstance(tdef, include):
#     561     # it's a state reference
#     562     assert tdef != state, f"circular state reference {state!r}"
# --> 563     tokens.extend(cls._process_state(unprocessed, processed,
#     564                                      str(tdef)))
#     565     continue
#     566 if isinstance(tdef, _inherit):
#     567     # should be processed already, but may not in the case of:
#     568     # 1. the state has no counterpart in any parent
#     569     # 2. the state includes more than one 'inherit'
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/lexer.py:579, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     576 assert type(tdef) is tuple, f"wrong rule def {tdef!r}"
#     578 try:
# --> 579     rex = cls._process_regex(tdef[0], rflags, state)
#     580 except Exception as err:
#     581     raise ValueError(f"uncompilable regex {tdef[0]!r} in state {state!r} of {cls!r}: {err}") from err
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/lexer.py:507, in RegexLexerMeta._process_regex(cls, regex, rflags, state)
#     505 """Preprocess the regular expression component of a token definition."""
#     506 if isinstance(regex, Future):
# --> 507     regex = regex.get()
#     508 return re.compile(regex, rflags).match
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/lexer.py:495, in words.get(self)
#     494 def get(self):
# --> 495     return regex_opt(self.words, prefix=self.prefix, suffix=self.suffix)
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/regexopt.py:91, in regex_opt(strings, prefix, suffix)
#      83 """Return a compiled regex that matches any string in the given list.
#      84
#      85 The strings to match must be literal strings, not regexes.  They will be
#    (...)     88 *prefix* and *suffix* are pre- and appended to the final regex.
#      89 """
#      90 strings = sorted(strings)
# ---> 91 return prefix + regex_opt_inner(strings, '(') + suffix
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
#     [... skipping similar frames: <genexpr> at line 77 (1 times), regex_opt_inner at line 77 (1 times)]
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/regexopt.py:63, in regex_opt_inner(strings, open_paren)
#      59     plen = len(prefix)
#      60     # we have a prefix for all strings
#      61     # print '-> prefix:', prefix
#      62     return open_paren + escape(prefix) \
# ---> 63         + regex_opt_inner([s[plen:] for s in strings], '(?:') \
#      64         + close_paren
#      65 # is there a suffix?
#      66 strings_rev = [s[::-1] for s in strings]
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File ~/Documents/RIT_HW/Fall 25/Grading/CSCI-635-01-Group-4/.venv/lib/python3.12/site-packages/pygments/regexopt.py:78, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
#      77     '|'.join(regex_opt_inner(list(group[1]), '')
# ---> 78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# KeyboardInterrupt:

# %%
n_clusters = [900, 1000, 1100, 1200, 1300, 1400, 1500]
WCCS = []

for k in n_clusters:
    kmeans = KMeans(n_clusters=k, random_state=RANDOM_STATE, n_init=10)
    kmeans.fit(pca_np)

    inertia = kmeans.inertia_
    WCCS.append(inertia)
    print(f"WCCS for {k}: {inertia}")



plt.plot(n_clusters, WCCS, color="navy", marker="o")
plt.xlabel("n_clusters")
plt.ylabel("WCCS")
plt.title("WCCS by cluster")
plt.show()
# took 1h 13m
# Out:
# WCCS for 900: 7404.493364117585
# WCCS for 1000: 6654.014990560607
# WCCS for 1100: 6056.988611396544
# WCCS for 1200: 5549.394745729058
# WCCS for 1300: 5131.824219577855
# WCCS for 1400: 4757.300789463736
# WCCS for 1500: 4440.3253641452075

# %%
# plt.figure(figsize=(12, 8))
# plt.scatter(pca_np[:, 0], pca_np[:, 1], c=labels, cmap='viridis', s=1, alpha=0.8, facecolors="none")
# plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='X', s=10, label='Centroids')
# plt.title('K-Means Clustering (2D Data)')
# plt.xlabel('Feature 1')
# plt.ylabel('Feature 2')
# plt.legend()
# plt.grid(True)
# plt.show()
